# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-36-bd2a15f27add> in <module>()
#      19     return X_train, y_train, X_val, y_val, X_test, y_test
#      20
# ---> 21 X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
#
# <ipython-input-36-bd2a15f27add> in get_CIFAR10_data(num_training, num_validation, num_test)
#       4     # Load the raw CIFAR-10 data
#       5     cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
# ----> 6     X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
#       7
#       8     # Subsample the data
#
# /home/fchen14/cs231n/assignment1/cs231n/data_utils.pyc in load_CIFAR10(ROOT)
#      37   Ytr = np.concatenate(ys)
#      38   del X, Y
# ---> 39   Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
#      40   return Xtr, Ytr, Xte, Yte
#      41
#
# /home/fchen14/cs231n/assignment1/cs231n/data_utils.pyc in load_CIFAR_batch(filename)
#      21     X = datadict['data']
#      22     Y = datadict['labels']
# ---> 23     X = X.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float")
#      24     Y = np.array(Y)
#      25     return X, Y
#
# MemoryError:

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 30 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

#learning_rates = [1e-9, 1e-8, 1e-7]
learning_rates = np.linspace(5e-10, 5e-9, num=10, endpoint=True)
#regularization_strengths = [5e4, 5e5, 5e6]
#regularization_strengths = [8e5, 5e6, 5.1e6, 5.2e6, 5.3e6]
regularization_strengths = np.linspace(5.5e6, 2e7, num=10, endpoint=True)

results = {}
best_val = -1
best_svm = None

#pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
#lr_vals = np.linspace(learning_rates[0], learning_rates[1], num=10, endpoint=True)
#rs_vals = np.linspace(regularization_strengths[0], regularization_strengths[1], num=10, endpoint=True)
#rs_vals = np.linspace(np.log(regularization_strengths[0]),np.log(regularization_strengths[1]), num=10, endpoint=True)
#rs_vals = np.exp(rs_vals)
#print(lr_vals)
#print(rs_vals)
nit_small = 3000
nit_large = 20*nit_small
for lr in learning_rates: #lr_vals:
    for rs in regularization_strengths: #rs_vals:
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs,
                      num_iters=nit_small, verbose=False)
        y_train_pred_feats = svm.predict(X_train_feats)
        trn_acc = np.mean(y_train == y_train_pred_feats)
        y_val_pred = svm.predict(X_val_feats)
        val_acc = np.mean(y_val == y_val_pred)
        results[(lr, rs)] = (trn_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_svm = svm
            best_lr = lr
            best_rs = rs

print("best_lr,best_rs,best_val", best_lr, best_rs, best_val)

best_svm = LinearSVM()
loss_hist = best_svm.train(X_train_feats, y_train, learning_rate=best_lr, reg=best_rs,
                      num_iters=nit_large, verbose=False)
y_val_pred_feats = best_svm.predict(X_val_feats)
best_val = np.mean(y_val == y_val_pred_feats)
print("best_val_acc1= %f" % best_val)
#pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# best_lr,best_rs,best_val 5e-10 18388888.8889 0.446
# best_val_acc1= 0.430000
# lr 5.000000e-10 reg 5.500000e+06 train accuracy: 0.423102 val accuracy: 0.425000
# lr 5.000000e-10 reg 7.111111e+06 train accuracy: 0.423286 val accuracy: 0.424000
# lr 5.000000e-10 reg 8.722222e+06 train accuracy: 0.426347 val accuracy: 0.436000
# lr 5.000000e-10 reg 1.033333e+07 train accuracy: 0.425816 val accuracy: 0.431000
# lr 5.000000e-10 reg 1.194444e+07 train accuracy: 0.421061 val accuracy: 0.422000
# lr 5.000000e-10 reg 1.355556e+07 train accuracy: 0.420837 val accuracy: 0.410000
# lr 5.000000e-10 reg 1.516667e+07 train accuracy: 0.421816 val accuracy: 0.415000
# lr 5.000000e-10 reg 1.677778e+07 train accuracy: 0.424041 val accuracy: 0.427000
# lr 5.000000e-10 reg 1.838889e+07 train accuracy: 0.425204 val accuracy: 0.446000
# lr 5.000000e-10 reg 2.000000e+07 train accuracy: 0.420857 val accuracy: 0.419000
# lr 1.000000e-09 reg 5.500000e+06 train accuracy: 0.426327 val accuracy: 0.429000
# lr 1.000000e-09 reg 7.111111e+06 train accuracy: 0.423347 val accuracy: 0.430000
# lr 1.000000e-09 reg 8.722222e+06 train accuracy: 0.419429 val accuracy: 0.415000
# lr 1.000000e-09 reg 1.033333e+07 train accuracy: 0.425367 val accuracy: 0.430000
# lr 1.000000e-09 reg 1.194444e+07 train accuracy: 0.420000 val accuracy: 0.417000
# lr 1.000000e-09 reg 1.355556e+07 train accuracy: 0.424429 val accuracy: 0.424000
# lr 1.000000e-09 reg 1.516667e+07 train accuracy: 0.421612 val accuracy: 0.412000
# lr 1.000000e-09 reg 1.677778e+07 train accuracy: 0.420429 val accuracy: 0.431000
# lr 1.000000e-09 reg 1.838889e+07 train accuracy: 0.426714 val accuracy: 0.421000
# lr 1.000000e-09 reg 2.000000e+07 train accuracy: 0.424633 val accuracy: 0.436000
# lr 1.500000e-09 reg 5.500000e+06 train accuracy: 0.423796 val accuracy: 0.429000
# lr 1.500000e-09 reg 7.111111e+06 train accuracy: 0.423041 val accuracy: 0.420000
# lr 1.500000e-09 reg 8.722222e+06 train accuracy: 0.415980 val accuracy: 0.414000
# lr 1.500000e-09 reg 1.033333e+07 train accuracy: 0.422612 val accuracy: 0.426000
# lr 1.500000e-09 reg 1.194444e+07 train accuracy: 0.418163 val accuracy: 0.421000
# lr 1.500000e-09 reg 1.355556e+07 train accuracy: 0.421898 val accuracy: 0.417000
# lr 1.500000e-09 reg 1.516667e+07 train accuracy: 0.420592 val accuracy: 0.423000
# lr 1.500000e-09 reg 1.677778e+07 train accuracy: 0.422469 val accuracy: 0.419000
# lr 1.500000e-09 reg 1.838889e+07 train accuracy: 0.414449 val accuracy: 0.407000
# lr 1.500000e-09 reg 2.000000e+07 train accuracy: 0.416020 val accuracy: 0.407000
# lr 2.000000e-09 reg 5.500000e+06 train accuracy: 0.426469 val accuracy: 0.422000
# lr 2.000000e-09 reg 7.111111e+06 train accuracy: 0.428224 val accuracy: 0.435000
# lr 2.000000e-09 reg 8.722222e+06 train accuracy: 0.415939 val accuracy: 0.423000
# lr 2.000000e-09 reg 1.033333e+07 train accuracy: 0.425306 val accuracy: 0.433000
# lr 2.000000e-09 reg 1.194444e+07 train accuracy: 0.422531 val accuracy: 0.414000
# lr 2.000000e-09 reg 1.355556e+07 train accuracy: 0.423837 val accuracy: 0.434000
# lr 2.000000e-09 reg 1.516667e+07 train accuracy: 0.417204 val accuracy: 0.416000
# lr 2.000000e-09 reg 1.677778e+07 train accuracy: 0.419653 val accuracy: 0.427000
# lr 2.000000e-09 reg 1.838889e+07 train accuracy: 0.421367 val accuracy: 0.420000
# lr 2.000000e-09 reg 2.000000e+07 train accuracy: 0.416673 val accuracy: 0.412000
# lr 2.500000e-09 reg 5.500000e+06 train accuracy: 0.422959 val accuracy: 0.433000
# lr 2.500000e-09 reg 7.111111e+06 train accuracy: 0.421143 val accuracy: 0.418000
# lr 2.500000e-09 reg 8.722222e+06 train accuracy: 0.424959 val accuracy: 0.431000
# lr 2.500000e-09 reg 1.033333e+07 train accuracy: 0.419837 val accuracy: 0.408000
# lr 2.500000e-09 reg 1.194444e+07 train accuracy: 0.417633 val accuracy: 0.410000
# lr 2.500000e-09 reg 1.355556e+07 train accuracy: 0.418490 val accuracy: 0.427000
# lr 2.500000e-09 reg 1.516667e+07 train accuracy: 0.420429 val accuracy: 0.413000
# lr 2.500000e-09 reg 1.677778e+07 train accuracy: 0.414673 val accuracy: 0.397000
# lr 2.500000e-09 reg 1.838889e+07 train accuracy: 0.414224 val accuracy: 0.413000
# lr 2.500000e-09 reg 2.000000e+07 train accuracy: 0.419224 val accuracy: 0.419000
# lr 3.000000e-09 reg 5.500000e+06 train accuracy: 0.422143 val accuracy: 0.421000
# lr 3.000000e-09 reg 7.111111e+06 train accuracy: 0.424020 val accuracy: 0.426000
# lr 3.000000e-09 reg 8.722222e+06 train accuracy: 0.420592 val accuracy: 0.429000
# lr 3.000000e-09 reg 1.033333e+07 train accuracy: 0.419735 val accuracy: 0.441000
# lr 3.000000e-09 reg 1.194444e+07 train accuracy: 0.421469 val accuracy: 0.423000
# lr 3.000000e-09 reg 1.355556e+07 train accuracy: 0.415694 val accuracy: 0.420000
# lr 3.000000e-09 reg 1.516667e+07 train accuracy: 0.412673 val accuracy: 0.424000
# lr 3.000000e-09 reg 1.677778e+07 train accuracy: 0.423347 val accuracy: 0.419000
# lr 3.000000e-09 reg 1.838889e+07 train accuracy: 0.415816 val accuracy: 0.405000
# lr 3.000000e-09 reg 2.000000e+07 train accuracy: 0.403755 val accuracy: 0.397000
# lr 3.500000e-09 reg 5.500000e+06 train accuracy: 0.419163 val accuracy: 0.394000
# lr 3.500000e-09 reg 7.111111e+06 train accuracy: 0.416490 val accuracy: 0.427000
# lr 3.500000e-09 reg 8.722222e+06 train accuracy: 0.419490 val accuracy: 0.413000
# lr 3.500000e-09 reg 1.033333e+07 train accuracy: 0.421837 val accuracy: 0.429000
# lr 3.500000e-09 reg 1.194444e+07 train accuracy: 0.425163 val accuracy: 0.429000
# lr 3.500000e-09 reg 1.355556e+07 train accuracy: 0.412673 val accuracy: 0.402000
# lr 3.500000e-09 reg 1.516667e+07 train accuracy: 0.417694 val accuracy: 0.418000
# lr 3.500000e-09 reg 1.677778e+07 train accuracy: 0.421347 val accuracy: 0.426000
# lr 3.500000e-09 reg 1.838889e+07 train accuracy: 0.415653 val accuracy: 0.421000
# lr 3.500000e-09 reg 2.000000e+07 train accuracy: 0.406184 val accuracy: 0.404000
# lr 4.000000e-09 reg 5.500000e+06 train accuracy: 0.425633 val accuracy: 0.422000
# lr 4.000000e-09 reg 7.111111e+06 train accuracy: 0.414000 val accuracy: 0.410000
# lr 4.000000e-09 reg 8.722222e+06 train accuracy: 0.414122 val accuracy: 0.420000
# lr 4.000000e-09 reg 1.033333e+07 train accuracy: 0.418755 val accuracy: 0.434000
# lr 4.000000e-09 reg 1.194444e+07 train accuracy: 0.402449 val accuracy: 0.403000
# lr 4.000000e-09 reg 1.355556e+07 train accuracy: 0.413878 val accuracy: 0.428000
# lr 4.000000e-09 reg 1.516667e+07 train accuracy: 0.404143 val accuracy: 0.390000
# lr 4.000000e-09 reg 1.677778e+07 train accuracy: 0.419714 val accuracy: 0.417000
# lr 4.000000e-09 reg 1.838889e+07 train accuracy: 0.419061 val accuracy: 0.416000
# lr 4.000000e-09 reg 2.000000e+07 train accuracy: 0.414755 val accuracy: 0.424000
# lr 4.500000e-09 reg 5.500000e+06 train accuracy: 0.413265 val accuracy: 0.412000
# lr 4.500000e-09 reg 7.111111e+06 train accuracy: 0.415551 val accuracy: 0.409000
# lr 4.500000e-09 reg 8.722222e+06 train accuracy: 0.415857 val accuracy: 0.407000
# lr 4.500000e-09 reg 1.033333e+07 train accuracy: 0.411633 val accuracy: 0.423000
# lr 4.500000e-09 reg 1.194444e+07 train accuracy: 0.407735 val accuracy: 0.403000
# lr 4.500000e-09 reg 1.355556e+07 train accuracy: 0.418714 val accuracy: 0.417000
# lr 4.500000e-09 reg 1.516667e+07 train accuracy: 0.408388 val accuracy: 0.409000
# lr 4.500000e-09 reg 1.677778e+07 train accuracy: 0.405122 val accuracy: 0.388000
# lr 4.500000e-09 reg 1.838889e+07 train accuracy: 0.411878 val accuracy: 0.422000
# lr 4.500000e-09 reg 2.000000e+07 train accuracy: 0.400469 val accuracy: 0.400000
# lr 5.000000e-09 reg 5.500000e+06 train accuracy: 0.418469 val accuracy: 0.416000
# lr 5.000000e-09 reg 7.111111e+06 train accuracy: 0.422041 val accuracy: 0.428000
# lr 5.000000e-09 reg 8.722222e+06 train accuracy: 0.424020 val accuracy: 0.437000
# lr 5.000000e-09 reg 1.033333e+07 train accuracy: 0.414265 val accuracy: 0.414000
# lr 5.000000e-09 reg 1.194444e+07 train accuracy: 0.417082 val accuracy: 0.433000
# lr 5.000000e-09 reg 1.355556e+07 train accuracy: 0.406224 val accuracy: 0.397000
# lr 5.000000e-09 reg 1.516667e+07 train accuracy: 0.415286 val accuracy: 0.404000
# lr 5.000000e-09 reg 1.677778e+07 train accuracy: 0.410061 val accuracy: 0.389000
# lr 5.000000e-09 reg 1.838889e+07 train accuracy: 0.413367 val accuracy: 0.419000
# lr 5.000000e-09 reg 2.000000e+07 train accuracy: 0.408694 val accuracy: 0.404000
# best validation accuracy achieved during cross-validation: 0.430000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.42

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 175)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
print('input_dim=', input_dim)
hidden_dim = 300
num_classes = 10

print('X_train.shape=',X_train.shape)
print('X_train_feats.shape=',X_train_feats.shape)
net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
#best_net = None # store the best model into this 

#input_size = 32 * 32 * 3
#hidden_size = 50
#num_classes = 10

results = {}
best_val = -1
# learning_rates = [5e-4, 1e-3]
# regularization_strengths = [0.1, 0.25]
learning_rates = [1e-9, 1e-8]
regularization_strengths = [1e8, 5e8]
hidden_sizes = [200, 300]

lr_vals = np.linspace(learning_rates[0], learning_rates[1], num=1, endpoint=True)
rs_vals = np.linspace(regularization_strengths[0], regularization_strengths[1], num=1, endpoint=True)
#hs_vals = np.linspace(hidden_sizes[0], hidden_sizes[1], num=5, endpoint=True, dtype=int)
nit_small = 2000
nit_large = 10*nit_small
#for hs in hs_vals:
for lr in lr_vals:
    for rs in rs_vals:
#         net = TwoLayerNet(input_dim, hidden_dim, num_classes)
#             loss_hist = twolayernet.train(X_train, y_train, learning_rate=lr, reg=rs,
#                                           num_iters=nit_small, verbose=False)
#         stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
#                             num_iters=nit_small, batch_size=200,
#                             learning_rate=lr, learning_rate_decay=0.95,
#                             reg=rs, verbose=False)
#         y_train_pred = net.predict(X_train_feats)
#         trn_acc = np.mean(y_train == y_train_pred)
#         y_val_pred = net.predict(X_val_feats)
#         val_acc = np.mean(y_val == y_val_pred)
#         trn_acc = (net.predict(X_train_feats) == y_train).mean()
#         val_acc = (net.predict(X_val_feats) == y_val).mean()
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
#         stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
#                             num_iters=nit_small, batch_size=200,
#                             learning_rate=lr, learning_rate_decay=0.95,
#                             reg=rs, verbose=False)
        trn_acc = (net.predict(X_train_feats) == y_train).mean()
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        results[(lr, rs)] = (trn_acc, val_acc)
        print("lr,rs,trn_acc,val_acc:", lr, rs,trn_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            #best_hs = hs
            best_net = net
            best_lr = lr
            best_rs = rs

print("best_lr,best_rs,best_val", best_lr, best_rs, best_val)

# stats = best_net.train(X_train_feats, y_train, X_val, y_val,
#                                 num_iters=nit_large, batch_size=200,
#                                 learning_rate=best_lr, learning_rate_decay=0.95,
#                                 reg=best_rs, verbose=False)
# y_train_pred = net.predict(X_train_feats)
# trn_acc = np.mean(y_train == y_train_pred)
# y_val_pred = twolayernet.predict(X_val_feats)
# val_acc = np.mean(y_val == y_val_pred)
# results[(hs, lr, rs)] = (trn_acc, val_acc)
# print("best_large: hs,lr,rs,trn_acc,val_acc:",hs, lr, rs,trn_acc, val_acc)
#pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# input_dim= 175
# X_train.shape= (49000, 32, 32, 3)
# X_train_feats.shape= (49000, 175)
# lr,rs,trn_acc,val_acc: 1e-09 100000000.0 0.0850612244898 0.092
# best_lr,best_rs,best_val 1e-09 100000000.0 0.092

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
